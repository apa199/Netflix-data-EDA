# %% [markdown]
# <a href="https://colab.research.google.com/github/apa199/Netflix-data-EDA/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/apa199/Netflix-data-EDA/refs/heads/main/netflix_titles.csv'

# %%
column_names=["show_id", "type", "title", "director", "cast", "country", "date_added",
                "release_year", "rating", "duration", "listed_in", "description"]

# %%
df=pd.read_csv(url,names=column_names, header=None, on_bad_lines='skip')

# %%
df
# Out:
#       show_id     type                  title         director  \
# 0     show_id     type                  title         director
# 1          s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 2          s2  TV Show          Blood & Water              NaN
# 3          s3  TV Show              Ganglands  Julien Leclercq
# 4          s4  TV Show  Jailbirds New Orleans              NaN
# ...       ...      ...                    ...              ...
# 8803    s8803    Movie                 Zodiac    David Fincher
# 8804    s8804  TV Show            Zombie Dumb              NaN
# 8805    s8805    Movie             Zombieland  Ruben Fleischer
# 8806    s8806    Movie                   Zoom     Peter Hewitt
# 8807    s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                  cast        country
# ...

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# type          1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       show_id     type                          title             director  \
# 0     show_id     type                          title             director
# 8          s8    Movie                        Sankofa         Haile Gerima
# 9          s9  TV Show  The Great British Baking Show      Andy Devonshire
# 10        s10    Movie                   The Starling       Theodore Melfi
# 13        s13    Movie                   Je Suis Karl  Christian Schwochow
# ...       ...      ...                            ...                  ...
# 8802    s8802    Movie                        Zinzana      Majid Al Ansari
# 8803    s8803    Movie                         Zodiac        David Fincher
# 8805    s8805    Movie                     Zombieland      Ruben Fleischer
# 8806    s8806    Movie                           Zoom         Peter Hewitt
# 8807    s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
  movies = df[df['type'] == 'Movie']
  shows = df[df['type'] == 'TV Show']

# %%
movie_counts = movies['release_year'].value_counts().sort_index()

# %%
shows.head()
# Out:
#     show_id     type                                 title  \
# 9        s9  TV Show         The Great British Baking Show
# 199    s199  TV Show  King of Boys: The Return of the King
# 274    s274  TV Show                         Gone for Good
# 277    s277  TV Show                               Valeria
# 298    s298  TV Show                              Navarasa
#
#                                               director  \
# 9                                      Andy Devonshire
# 199                                       Kemi Adetiba
# 274                                 Juan Carlos Medina
# 277                                      Inma Torrente
# 298  Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
#
#                                                   cast         country  \
# 9    Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
# 199  Sola Sobowale, Toni Tones, Richard Mofe-Damijo...         Nigeria
# ...

# %%
import matplotlib.pyplot as plt

movie_counts.plot(kind='bar', figsize=(12, 5), color='skyblue')
plt.title("Number of Movies Released per Year")
plt.xlabel("Release Year")
plt.ylabel("Number of Movies")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
movies['cast']
# Out:
# 8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 10      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 13      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 25      Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 28      Adam Sandler, Kevin James, Chris Rock, David S...
#                               ...
# 8802    Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 5185, dtype: object

# %%
## top 10 actors in movies
movies['cast'] = movies['cast'].str.split(', ')
movies_exploded_cast = movies.explode('cast')
print(movies_exploded_cast['cast'].value_counts().head(10))
# Out:
# cast
# Anupam Kher          42
# Shah Rukh Khan       34
# Naseeruddin Shah     31
# Akshay Kumar         30
# Om Puri              30
# Amitabh Bachchan     28
# Paresh Rawal         28
# Boman Irani          27
# Kareena Kapoor       25
# Samuel L. Jackson    21
# Name: count, dtype: int64
# <ipython-input-104-e3284ec441c7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast'] = movies['cast'].str.split(', ')

# %%
## top 10 actors in movies
shows['cast'] = shows['cast'].str.split(', ')
shows_exploded_cast = shows.explode('cast')
print(shows_exploded_cast['cast'].value_counts().head(10))
# Out:
# cast
# David Attenborough       3
# M・A・O                    2
# Kaori Nazuka             2
# Prakash Raj              2
# Yusuke Kobayashi         2
# Gautham Vasudev Menon    2
# Anjali                   2
# Ai Kayano                2
# Ernesto Benjumea         2
# Katie McGrath            2
# Name: count, dtype: int64
# <ipython-input-105-b22a0273daaf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shows['cast'] = shows['cast'].str.split(', ')

# %%
#top 10 movie geners
movies['listed_in'].str.split(', ').explode().value_counts().head(10)
# Out:
# listed_in
# International Movies        2369
# Dramas                      2293
# Comedies                    1553
# Action & Adventure           806
# Independent Movies           740
# Romantic Movies              579
# Thrillers                    547
# Children & Family Movies     503
# Documentaries                391
# Horror Movies                336
# Name: count, dtype: int64

# %%
# top 10 shows geners
shows['listed_in'].str.split(', ').explode().value_counts().head(10)
# Out:
# listed_in
# International TV Shows          87
# TV Dramas                       52
# Crime TV Shows                  38
# TV Comedies                     30
# Romantic TV Shows               21
# British TV Shows                21
# Docuseries                      14
# TV Action & Adventure           13
# Kids' TV                        13
# Stand-Up Comedy & Talk Shows    11
# Name: count, dtype: int64

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month

# %%
df.drop(index=df.index[0], axis=0, inplace=True)

# %%
df
# Out:
#      show_id     type                          title             director  \
# 8         s8    Movie                        Sankofa         Haile Gerima
# 9         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 10       s10    Movie                   The Starling       Theodore Melfi
# 13       s13    Movie                   Je Suis Karl  Christian Schwochow
# 25       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8802   s8802    Movie                        Zinzana      Majid Al Ansari
# 8803   s8803    Movie                         Zodiac        David Fincher
# 8805   s8805    Movie                     Zombieland      Ruben Fleischer
# 8806   s8806    Movie                           Zoom         Peter Hewitt
# 8807   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
# top 10 directors
df['director'].value_counts().head(10)
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          11
# Don Michael Paul          10
# David Dhawan               9
# Name: count, dtype: int64

# %%
df['duration']
# Out:
# 8         125 min
# 9       9 Seasons
# 10        104 min
# 13        127 min
# 25        166 min
#           ...
# 8802       96 min
# 8803      158 min
# 8805       88 min
# 8806       88 min
# 8807      111 min
# Name: duration, Length: 5332, dtype: object

# %%
#avg duration of movie--> we sort to movie then replace the min then change the type from obj to int then mean
df[df['type'] == 'Movie']['duration'].str.replace(' min', '').astype(int).mean()
# Out:
# np.float64(102.70144648023144)

# %%
df[df['type'] == 'Movie']['duration'].str.replace(' min', '').astype(int).sort_values(ascending=False).head()
# Out:
# 2492    253
# 2488    237
# 167     229
# 7933    228
# 1020    224
# Name: duration, dtype: int64

# %%
df[df['type'] == 'Movie']['duration'].str.replace(' min', '').astype(int).plot(kind='hist')
plt.title('Movie Durations Distribution')
plt.xlabel('Duration (min)')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(x='type', data=df)
plt.title('Count of Movies and TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
genre_counts = df['listed_in'].value_counts().head(10)

# Pie chart for genre distribution
genre_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Genre Distribution')
plt.ylabel('')  # Hide the ylabel
plt.show()

# %%
director_counts = movies['director'].value_counts().head(10)

# Pie chart for genre distribution
director_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Director top 10 movies')
plt.ylabel('')  # Hide the ylabel
plt.show()

# %%
director_counts_shows=shows['director'].value_counts().head(10)
director_counts_shows.plot(kind='pie', autopct='%1.1f%%')
plt.title('Director top 10 movies')
plt.ylabel('')  # Hide the ylabel
plt.show()

# %%
yearly_count = df.groupby('year_added')['type'].count()

# Plot a line chart
yearly_count.plot(kind='line', marker='o', color='purple')
plt.title('Number of Movies/TV Shows Added Over Time')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()
